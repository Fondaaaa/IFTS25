# %%
import pandas as pd
import numpy as np

# Creare un DataFrame di esempio
data = {
    'Colonna1': [1, 2, 3, 4],
    'Colonna2': [5.1, 6.2, 7.3, 8.4],
    'Colonna3': ['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01'],
    'Colonna4': ['A', 'B', 'A', 'C'],
    'Colonna5': [True, False, True, False]
}

df = pd.DataFrame(data)
df
# Out:
#    Colonna1  Colonna2    Colonna3 Colonna4  Colonna5
# 0         1       5.1  2022-01-01        A      True
# 1         2       6.2  2022-02-01        B     False
# 2         3       7.3  2022-03-01        A      True
# 3         4       8.4  2022-04-01        C     False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Colonna1  4 non-null      int64
#  1   Colonna2  4 non-null      float64
#  2   Colonna3  4 non-null      object
#  3   Colonna4  4 non-null      object
#  4   Colonna5  4 non-null      bool
# dtypes: bool(1), float64(1), int64(1), object(2)
# memory usage: 264.0+ bytes

# %%
from numpy import float64
# 1. Convertire la Colonna1 da int a float

df["Colonna1"] = df["Colonna1"].astype(float64)
df["Colonna1"]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# Name: Colonna1, dtype: float64

# %%
# 2. Convertire la Colonna2 da float a int
df["Colonna2"] = df["Colonna2"].astype(int)
df["Colonna2"]
# Out:
# 0    5
# 1    6
# 2    7
# 3    8
# Name: Colonna2, dtype: int64

# %%
#datetime
# 3. Convertire la Colonna3 da stringa a data
df["Colonna3"] = pd.to_datetime(df["Colonna3"])
df["Colonna3"]
# Out:
# 0   2022-01-01
# 1   2022-02-01
# 2   2022-03-01
# 3   2022-04-01
# Name: Colonna3, dtype: datetime64[ns]

# %%
# 4. Convertire la Colonna3 da data a stringa
df["Colonna3"] = df["Colonna3"].astype("string")
df["Colonna3"]
# Out:
# 0    2022-01-01
# 1    2022-02-01
# 2    2022-03-01
# 3    2022-04-01
# Name: Colonna3, dtype: string

# %%
#category
# 5. Convertire la Colonna4 da object a categoria
df["Colonna4"] = df["Colonna4"].astype("category")
df["Colonna4"]
# Out:
# 0    A
# 1    B
# 2    A
# 3    C
# Name: Colonna4, dtype: category
# Categories (3, object): ['A', 'B', 'C']

# %%
# 6. Convertire la Colonna4 da categoria a object
df["Colonna4"] = df["Colonna4"].astype("string")
df["Colonna4"]
# Out:
# 0    A
# 1    B
# 2    A
# 3    C
# Name: Colonna4, dtype: string

# %%
# 7. Convertire più colonne contemporaneamente
#'Colonna1'float 'Colonna2'int 'Colonna4''category'
df.astype({"Colonna1" : float, "Colonna2":int,"Colonna4" : "category"})
# Out:
#    Colonna1  Colonna2    Colonna3 Colonna4  Colonna5
# 0       1.0         5  2022-01-01        A      True
# 1       2.0         6  2022-02-01        B     False
# 2       3.0         7  2022-03-01        A      True
# 3       4.0         8  2022-04-01        C     False

# %%
# 8. Convertire tutti i tipi di dati del DataFrame in float
"""df.astype(float)"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3758402549.py in <cell line: 0>()
#       1 # 8. Convertire tutti i tipi di dati del DataFrame in float
# ----> 2 df.astype(float)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in apply(self, f, align_keys, **kwargs)
#     361                 applied = b.apply(f, **kwargs)
#     362             else:
# --> 363                 applied = getattr(b, f)(**kwargs)
#     364             result_blocks = extend_blocks(applied, result_blocks)
#     365
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/blocks.py in astype(self, dtype, copy, errors, using_cow, squeeze)
#     756             values = values[0, :]  # type: ignore[call-overload]
#     757
# --> 758         new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     759
#     760         new_values = maybe_coerce_values(new_values)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array_safe(values, dtype, copy, errors)
#     235
#     236     try:
# --> 237         new_values = astype_array(values, dtype, copy=copy)
#     238     except (ValueError, TypeError):
#     239         # e.g. _astype_nansafe can fail on object-dtype of strings
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/dtypes/astype.py in astype_array(values, dtype, copy)
#     177     if not isinstance(values, np.ndarray):
#     178         # i.e. ExtensionArray
# --> 179         values = values.astype(dtype, copy=copy)
#     180
#     181     else:
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/arrays/string_.py in astype(self, dtype, copy)
#     509             mask = self.isna()
#     510             arr[mask] = 0
# --> 511             values = arr.astype(dtype)
#     512             values[mask] = np.nan
#     513             return values
#
# ValueError: could not convert string to float: 'A'

# %%
# 9. Convertire la Colonna5 da booleana a intero
df['Colonna5']=df['Colonna5'].astype(int)
df["Colonna5"]
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# Name: Colonna5, dtype: int64

# %%
# 10. Convertire la Colonna5 da intero a booleano
df["Colonna5"]=df["Colonna5"].astype(bool)
df["Colonna5"]
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# Name: Colonna5, dtype: bool
